# %% [markdown]
# ### Dreambooth Fine-tuning
# DreamBooth is a deep learning generation model used to fine-tune existing text-to-image models, developed by researchers from Google Research and Boston University in 2022. Originally developed using Google's own Imagen text-to-image model, DreamBooth implementations can be applied to other text-to-image models, where it can allow the model to generate more fine-tuned and personalised outputs after training on three to five images of a subject.
#
# We should use dreambooth fine tuning our stable diffusion model.
#
# #### Notebook step
# 1. Import boto3, sagemaker python SDK
# 2. Build dreambooth fine-tuning image
# 3. Fine-tuning
#    * config hyperparameter
#    * create training job
# 4. Testing

# %% [markdown]
# #### 1. Import boto3, sagemaker python SDK

# %%
import sagemaker
import boto3
from sagemaker.pytorch import PyTorch
sagemaker_session = sagemaker.Session()
bucket = sagemaker_session.default_bucket()
role = sagemaker.get_execution_role()
account_id = boto3.client('sts').get_caller_identity().get('Account')
region_name = boto3.session.Session().region_name

images_s3uri = 's3://{0}/dreambooth/images/'.format(bucket)
models_s3uri = 's3://{0}/stable-diffusion/models/'.format(bucket)
dreambooth_s3uri = 's3://{0}/stable-diffusion/dreambooth/'.format(bucket)

print(bucket)
# Out:
# sagemaker-us-east-1-596030579944

# %% [markdown]
# #### 2. Build dreambooth fine-tuning image
#   It will take 60~90 minutes if use small notebook instance(ml.t3.xlarge)

# %%
# !./build_push.sh
# Out:
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
# Cloning into 'sd_dreambooth_extension'...
# remote: Enumerating objects: 1933, done.
# remote: Counting objects: 100% (1933/1933), done.
# remote: Compressing objects: 100% (704/704), done.
# remote: Total 1933 (delta 1252), reused 1838 (delta 1164), pack-reused 0
# Receiving objects: 100% (1933/1933), 10.12 MiB | 18.78 MiB/s, done.
# Resolving deltas: 100% (1252/1252), done.
# Sending build context to Docker daemon  33.94MB
# Step 1/4 : FROM 596030579944.dkr.ecr.us-east-1.amazonaws.com/sd-dreambooth-finetuning
#  ---> 2da0a75a4b74
# Step 2/4 : RUN curl -L https://github.com/peak/s5cmd/releases/download/v2.0.0/s5cmd_2.0.0_Linux-64bit.tar.gz | tar -xz && mv s5cmd /opt/conda/bin/
#  ---> Using cache
#  ---> f74647431c54
# Step 3/4 : COPY train_dreambooth.py /opt/ml/code/
#  ---> 8647415dc9f2
# Step 4/4 : COPY ./sd_code/ /opt/ml/code/
#  ---> 1247d3df8c63
# Successfully built 1247d3df8c63
# Successfully tagged sd-dreambooth-finetuning-v2:latest
# The push refers to repository [596030579944.dkr.ecr.us-east-1.amazonaws.com/sd-dreambooth-finetuning-v2]
#
# f59889c2: Preparing
# 40d160e1: Preparing
# 34627d9f: Preparing
# 1fdc41dc: Preparing
# 49a33433: Preparing
# 3c0791cb: Preparing
# 3504c9fd: Preparing
# dfac196e: Preparing
# 4e364cea: Preparing
# 3a721f8b: Preparing
# 1f422c40: Preparing
# 184f13be: Preparing
# 4f87f8e7: Preparing
# 40097ffc: Preparing
# 88890620: Preparing
# bfa15408: Preparing
# 0648b8c6: Preparing
# a50e7b38: Preparing
# 0648b8c6: Pushed   10.88GB/10.83GBPushing   25.6MB/1.262GBPushing  680.1MB/10.83GBPushing  4.718GB/10.83GBlatest: digest: sha256:0140c9f9650458d39f63c3d4ada64eee96984b955117bea59db9749f031b3403 size: 4335

# %% [markdown]
# #### 3. Fine-tuning
#
#    * image_uri: docker image ecr URI
#    * instance_type: training job instance , prefere ml.g4dn.xlarge, ml.g5.xlarge
#    * class_prompt: class prompt
#    * instance_prompt: your image key prompt
#    * model_name: pretrained_model

# %%
import json
def json_encode_hyperparameters(hyperparameters):
    for (k, v) in hyperparameters.items():
        print(k, v)
    
    return {k: json.dumps(v) for (k, v) in hyperparameters.items()}




image_uri = f'{account_id}.dkr.ecr.{region_name}.amazonaws.com/sd-dreambooth-finetuning-v2'
instance_type = 'ml.g4dn.2xlarge'

instance_prompt="photo\ of\ zwx\  man"
class_prompt="photo\ of\ a\ man"
s3_model_output_location='s3://{}/{}/{}'.format(bucket, 'dreambooth', 'trained_models')
model_name="runwayml/stable-diffusion-v1-5"
instance_dir="/opt/ml/input/data/images/"
class_dir="/opt/ml/input/data/class_images/"



environment = {
    'PYTORCH_CUDA_ALLOC_CONF':'max_split_size_mb:32',
    'LD_LIBRARY_PATH':"${LD_LIBRARY_PATH}:/opt/conda/lib/"
}

hyperparameters = {
                    'model_name':'aws-trained-dreambooth-model',
                    'mixed_precision':'fp16',
                    'pretrained_model_name_or_path': model_name, 
                    'instance_data_dir':instance_dir,
                    'class_data_dir':class_dir,
                    'with_prior_preservation':True,
                    'models_path': '/opt/ml/model/',
                    'instance_prompt': instance_prompt, 
                    'class_prompt':class_prompt,
                    'resolution':512,
                    'train_batch_size':1,
                    'sample_batch_size': 1,
                    'gradient_accumulation_steps':1,
                    'learning_rate':2e-06,
                    'lr_scheduler':'constant',
                    'lr_warmup_steps':0,
                    'num_class_images':50,
                    'max_train_steps':300,
                    'save_steps':300,
                    'attention':'xformers',
                    'prior_loss_weight': 0.5,
                    'use_ema':True,
                    'train_text_encoder':False,
                    'not_cache_latents':True,
                    'gradient_checkpointing':True,
                    'save_use_epochs': False,
                    'use_8bit_adam': False
}

hyperparameters = json_encode_hyperparameters(hyperparameters)
# Out:
# model_name aws-trained-dreambooth-model
# mixed_precision fp16
# pretrained_model_name_or_path runwayml/stable-diffusion-v1-5
# instance_data_dir /opt/ml/input/data/images/
# class_data_dir /opt/ml/input/data/class_images/
# with_prior_preservation True
# models_path /opt/ml/model/
# instance_prompt photo\ of\ zwx\  man
# class_prompt photo\ of\ a\ man
# resolution 512
# train_batch_size 1
# sample_batch_size 1
# gradient_accumulation_steps 1
# learning_rate 2e-06
# lr_scheduler constant
# lr_warmup_steps 0
# num_class_images 50
# max_train_steps 300
# save_steps 300
# attention xformers
# prior_loss_weight 0.5
# use_ema True
# train_text_encoder False
# not_cache_latents True
# gradient_checkpointing True
# save_use_epochs False
# use_8bit_adam False

# %% [markdown]
#    * Create training job

# %%
from sagemaker.estimator import Estimator
inputs = {
    'images': f"s3://sagemaker-{region_name}-{account_id}/dreambooth/images/"
}


estimator = Estimator(
    role = role,
    instance_count=1,
    instance_type = instance_type,
    image_uri = image_uri,
    hyperparameters = hyperparameters,
    environment = environment
)
estimator.fit(inputs)
# Out:
# INFO:sagemaker:Creating training-job with name: sd-dreambooth-finetuning-quickupload-2023-02-21-03-04-13-395
# 2023-02-21 03:04:13 Starting - Starting the training job...
# 2023-02-21 03:04:28 Starting - Preparing the instances for training......
# 2023-02-21 03:05:27 Downloading - Downloading input data...
# 2023-02-21 03:05:47 Training - Downloading the training image.................................
# 2023-02-21 03:11:29 Training - Training image download completed. Training in progress....2023-02-21 03:11:59,536 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2023-02-21 03:11:59,569 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2023-02-21 03:11:59,601 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2023-02-21 03:11:59,612 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "images": "/opt/ml/input/data/images"
#     },
#     "current_host": "algo-1",
#     "current_instance_group": "homogeneousCluster",
#     "current_instance_group_hosts": [
#         "algo-1"
#     ],
#     "current_instance_type": "ml.g4dn.2xlarge",
#     "distribution_hosts": [],
#     "distribution_instance_groups": [],
#     "framework_module": null,
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "attention": "xformers",
#         "class_data_dir": "/opt/ml/input/data/class_images/",
#         "class_prompt": "photo\\ of\\ a\\ man",
#         "gradient_accumulation_steps": 1,
#         "gradient_checkpointing": true,
#         "instance_data_dir": "/opt/ml/input/data/images/",
#         "instance_prompt": "photo\\ of\\ zwx\\  man",
#         "learning_rate": 2e-06,
#         "lr_scheduler": "constant",
#         "lr_warmup_steps": 0,
#         "max_train_steps": 300,
#         "mixed_precision": "fp16",
#         "model_name": "aws-trained-dreambooth-model",
#         "models_path": "/opt/ml/model/",
#         "not_cache_latents": true,
#         "num_class_images": 50,
#         "pretrained_model_name_or_path": "runwayml/stable-diffusion-v1-5",
#         "prior_loss_weight": 0.5,
#         "resolution": 512,
#         "sample_batch_size": 1,
#         "save_steps": 300,
#         "save_use_epochs": false,
#         "train_batch_size": 1,
#         "train_text_encoder": false,
#         "use_8bit_adam": false,
#         "use_ema": true,
#         "with_prior_preservation": true
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "images": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "instance_groups": [
#         "homogeneousCluster"
#     ],
#     "instance_groups_dict": {
#         "homogeneousCluster": {
#             "instance_group_name": "homogeneousCluster",
#             "instance_type": "ml.g4dn.2xlarge",
#             "hosts": [
#                 "algo-1"
#             ]
#         }
#     },
#     "is_hetero": false,
#     "is_master": true,
#     "is_modelparallel_enabled": null,
#     "is_smddpmprun_installed": false,
#     "job_name": "sd-dreambooth-finetuning-quickupload-2023-02-21-03-04-13-395",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "/opt/ml/code",
#     "module_name": "train_dreambooth",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "num_neurons": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.g4dn.2xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.g4dn.2xlarge",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train_dreambooth.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"attention":"xformers","class_data_dir":"/opt/ml/input/data/class_images/","class_prompt":"photo\\ of\\ a\\ man","gradient_accumulation_steps":1,"gradient_checkpointing":true,"instance_data_dir":"/opt/ml/input/data/images/","instance_prompt":"photo\\ of\\ zwx\\  man","learning_rate":2e-06,"lr_scheduler":"constant","lr_warmup_steps":0,"max_train_steps":300,"mixed_precision":"fp16","model_name":"aws-trained-dreambooth-model","models_path":"/opt/ml/model/","not_cache_latents":true,"num_class_images":50,"pretrained_model_name_or_path":"runwayml/stable-diffusion-v1-5","prior_loss_weight":0.5,"resolution":512,"sample_batch_size":1,"save_steps":300,"save_use_epochs":false,"train_batch_size":1,"train_text_encoder":false,"use_8bit_adam":false,"use_ema":true,"with_prior_preservation":true}
# SM_USER_ENTRY_POINT=train_dreambooth.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.g4dn.2xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.g4dn.2xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"images":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["images"]
# SM_CURRENT_HOST=algo-1
# SM_CURRENT_INSTANCE_TYPE=ml.g4dn.2xlarge
# SM_CURRENT_INSTANCE_GROUP=homogeneousCluster
# SM_CURRENT_INSTANCE_GROUP_HOSTS=["algo-1"]
# SM_INSTANCE_GROUPS=["homogeneousCluster"]
# SM_INSTANCE_GROUPS_DICT={"homogeneousCluster":{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.g4dn.2xlarge"}}
# SM_DISTRIBUTION_INSTANCE_GROUPS=[]
# SM_IS_HETERO=false
# SM_MODULE_NAME=train_dreambooth
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_NUM_NEURONS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=/opt/ml/code
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"images":"/opt/ml/input/data/images"},"current_host":"algo-1","current_instance_group":"homogeneousCluster","current_instance_group_hosts":["algo-1"],"current_instance_type":"ml.g4dn.2xlarge","distribution_hosts":[],"distribution_instance_groups":[],"framework_module":null,"hosts":["algo-1"],"hyperparameters":{"attention":"xformers","class_data_dir":"/opt/ml/input/data/class_images/","class_prompt":"photo\\ of\\ a\\ man","gradient_accumulation_steps":1,"gradient_checkpointing":true,"instance_data_dir":"/opt/ml/input/data/images/","instance_prompt":"photo\\ of\\ zwx\\  man","learning_rate":2e-06,"lr_scheduler":"constant","lr_warmup_steps":0,"max_train_steps":300,"mixed_precision":"fp16","model_name":"aws-trained-dreambooth-model","models_path":"/opt/ml/model/","not_cache_latents":true,"num_class_images":50,"pretrained_model_name_or_path":"runwayml/stable-diffusion-v1-5","prior_loss_weight":0.5,"resolution":512,"sample_batch_size":1,"save_steps":300,"save_use_epochs":false,"train_batch_size":1,"train_text_encoder":false,"use_8bit_adam":false,"use_ema":true,"with_prior_preservation":true},"input_config_dir":"/opt/ml/input/config","input_data_config":{"images":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","instance_groups":["homogeneousCluster"],"instance_groups_dict":{"homogeneousCluster":{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.g4dn.2xlarge"}},"is_hetero":false,"is_master":true,"is_modelparallel_enabled":null,"is_smddpmprun_installed":false,"job_name":"sd-dreambooth-finetuning-quickupload-2023-02-21-03-04-13-395","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"/opt/ml/code","module_name":"train_dreambooth","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"num_neurons":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.g4dn.2xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.g4dn.2xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"train_dreambooth.py"}
# SM_USER_ARGS=["--attention","xformers","--class_data_dir","/opt/ml/input/data/class_images/","--class_prompt","photo\\ of\\ a\\ man","--gradient_accumulation_steps","1","--gradient_checkpointing","True","--instance_data_dir","/opt/ml/input/data/images/","--instance_prompt","photo\\ of\\ zwx\\  man","--learning_rate","2e-06","--lr_scheduler","constant","--lr_warmup_steps","0","--max_train_steps","300","--mixed_precision","fp16","--model_name","aws-trained-dreambooth-model","--models_path","/opt/ml/model/","--not_cache_latents","True","--num_class_images","50","--pretrained_model_name_or_path","runwayml/stable-diffusion-v1-5","--prior_loss_weight","0.5","--resolution","512","--sample_batch_size","1","--save_steps","300","--save_use_epochs","False","--train_batch_size","1","--train_text_encoder","False","--use_8bit_adam","False","--use_ema","True","--with_prior_preservation","True"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_IMAGES=/opt/ml/input/data/images
# SM_HP_ATTENTION=xformers
# SM_HP_CLASS_DATA_DIR=/opt/ml/input/data/class_images/
# SM_HP_CLASS_PROMPT=photo\ of\ a\ man
# SM_HP_GRADIENT_ACCUMULATION_STEPS=1
# SM_HP_GRADIENT_CHECKPOINTING=true
# SM_HP_INSTANCE_DATA_DIR=/opt/ml/input/data/images/
# SM_HP_INSTANCE_PROMPT=photo\ of\ zwx\  man
# SM_HP_LEARNING_RATE=2e-06
# SM_HP_LR_SCHEDULER=constant
# SM_HP_LR_WARMUP_STEPS=0
# SM_HP_MAX_TRAIN_STEPS=300
# SM_HP_MIXED_PRECISION=fp16
# SM_HP_MODEL_NAME=aws-trained-dreambooth-model
# SM_HP_MODELS_PATH=/opt/ml/model/
# SM_HP_NOT_CACHE_LATENTS=true
# SM_HP_NUM_CLASS_IMAGES=50
# SM_HP_PRETRAINED_MODEL_NAME_OR_PATH=runwayml/stable-diffusion-v1-5
# SM_HP_PRIOR_LOSS_WEIGHT=0.5
# SM_HP_RESOLUTION=512
# SM_HP_SAMPLE_BATCH_SIZE=1
# SM_HP_SAVE_STEPS=300
# SM_HP_SAVE_USE_EPOCHS=false
# SM_HP_TRAIN_BATCH_SIZE=1
# SM_HP_TRAIN_TEXT_ENCODER=false
# SM_HP_USE_8BIT_ADAM=false
# SM_HP_USE_EMA=true
# SM_HP_WITH_PRIOR_PRESERVATION=true
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python39.zip:/opt/conda/lib/python3.9:/opt/conda/lib/python3.9/lib-dynload:/opt/conda/lib/python3.9/site-packages:/opt/ml/code/repositories/xformers
# Invoking script with the following command:
# /opt/conda/bin/python train_dreambooth.py --attention xformers --class_data_dir /opt/ml/input/data/class_images/ --class_prompt photo\ of\ a\ man --gradient_accumulation_steps 1 --gradient_checkpointing True --instance_data_dir /opt/ml/input/data/images/ --instance_prompt photo\ of\ zwx\  man --learning_rate 2e-06 --lr_scheduler constant --lr_warmup_steps 0 --max_train_steps 300 --mixed_precision fp16 --model_name aws-trained-dreambooth-model --models_path /opt/ml/model/ --not_cache_latents True --num_class_images 50 --pretrained_model_name_or_path runwayml/stable-diffusion-v1-5 --prior_loss_weight 0.5 --resolution 512 --sample_batch_size 1 --save_steps 300 --save_use_epochs False --train_batch_size 1 --train_text_encoder False --use_8bit_adam False --use_ema True --with_prior_preservation True
# 2023-02-21 03:11:59,612 sagemaker-training-toolkit INFO     Exceptions not imported for SageMaker Debugger as it is not installed.
# 2023-02-21 03:11:59,613 sagemaker-training-toolkit INFO     Exceptions not imported for SageMaker TF as Tensorflow is not installed.
# /opt/conda/lib/python3.9/site-packages/transformers/generation_utils.py:24: FutureWarning: Importing `GenerationMixin` from `src/transformers/generation_utils.py` is deprecated and will be removed in Transformers v5. Import as `from transformers import GenerationMixin` instead.
#   warnings.warn(
# Patching transformers to fix kwargs errors.
# {'model_name': 'aws-trained-dreambooth-model', 'models_path': '/opt/ml/model/', 'use_lora': False, 'use_cpu': False, 'lora_models_path': None, 'pretrained_model_name_or_path': 'runwayml/stable-diffusion-v1-5', 'pretrained_vae_name_or_path': None, 'revision': None, 'tokenizer_name': None, 'instance_data_dir': '/opt/ml/input/data/images/', 'class_data_dir': '/opt/ml/input/data/class_images/', 'instance_prompt': 'photo\\ of\\ zwx\\  man', 'class_prompt': 'photo\\ of\\ a\\ man', 'pad_tokens': False, 'with_prior_preservation': True, 'save_use_global_counts': False, 'save_use_epochs': True, 'prior_loss_weight': 0.5, 'num_class_images': 50, 'output_dir': 'text-inversion-model', 'seed': -1, 'resolution': 512, 'center_crop': False, 'train_text_encoder': 'False', 'train_batch_size': 1, 'sample_batch_size': 1, 'num_train_epochs': 1, 'max_train_steps': 300, 'epoch': 0, 'save_steps': 300, 'gradient_accumulation_steps': 1, 'gradient_checkpointing': True, 'learning_rate': 2e-06, 'scale_lr': False, 'lr_scheduler': 'constant', 'lr_warmup_steps': 0, 'use_8bit_adam': True, 'adam_beta1': 0.9, 'adam_beta2': 0.999, 'adam_weight_decay': 0.01, 'adam_epsilon': 1e-08, 'push_to_hub': False, 'hub_token': None, 'hub_model_id': None, 'logging_dir': 'logs', 'mixed_precision': 'fp16', 'not_cache_latents': 'True', 'hflip': False, 'local_rank': -1, 'concepts_list': [{'instance_prompt': 'photo\\ of\\ zwx\\  man', 'class_prompt': 'photo\\ of\\ a\\ man', 'instance_data_dir': '/opt/ml/input/data/images/', 'class_data_dir': '/opt/ml/input/data/class_images/', 'num_class_images': 50, 'instance_token': '', 'class_token': '', 'class_negative_prompt': '', 'class_guidance_scale': 7.5, 'class_infer_steps': 60}], 'use_ema': True, 'max_token_length': 75, 'half_model': False, 'attention': 'xformers', 'shuffle_tags': False}
# Replace CrossAttention.forward to use xformers
# Checking concept: {'instance_prompt': 'photo\\ of\\ zwx\\  man', 'class_prompt': 'photo\\ of\\ a\\ man', 'instance_data_dir': '/opt/ml/input/data/images/', 'class_data_dir': '/opt/ml/input/data/class_images/', 'num_class_images': 50, 'instance_token': '', 'class_token': '', 'class_negative_prompt': '', 'class_guidance_scale': 7.5, 'class_infer_steps': 60}
# Concept requires 50 images.
# Class dir /opt/ml/input/data/class_images has 0 images.
# #015Downloading (…)_model.safetensors";:   0%|          | 0.00/335M [00:00<?, ?B/s]#015Downloading (…)_model.safetensors";:   9%|▉         | 31.5M/335M [00:00<00:01, 254MB/s]#015Downloading (…)_model.safetensors";:  19%|█▉        | 62.9M/335M [00:00<00:01, 270MB/s]#015Downloading (…)_model.safetensors";:  31%|███▏      | 105M/335M [00:00<00:00, 319MB/s] #015Downloading (…)_model.safetensors";:  44%|████▍     | 147M/335M [00:00<00:00, 318MB/s]#015Downloading (…)_model.safetensors";:  56%|█████▋    | 189M/335M [00:00<00:00, 335MB/s]#015Downloading (…)_model.safetensors";:  69%|██████▉   | 231M/335M [00:00<00:00, 337MB/s]#015Downloading (…)_model.safetensors";:  81%|████████▏ | 273M/335M [00:00<00:00, 284MB/s]#015Downloading (…)_model.safetensors";:  94%|█████████▍| 315M/335M [00:01<00:00, 308MB/s]#015Downloading (…)_model.safetensors";: 100%|██████████| 335M/335M [00:01<00:00, 312MB/s]
# #015Downloading (…)main/vae/config.json:   0%|          | 0.00/547 [00:00<?, ?B/s]#015Downloading (…)main/vae/config.json: 100%|██████████| 547/547 [00:00<00:00, 78.3kB/s]
# #015Downloading (…)ain/model_index.json:   0%|          | 0.00/543 [00:00<?, ?B/s]#015Downloading (…)ain/model_index.json: 100%|██████████| 543/543 [00:00<00:00, 77.6kB/s]
# #015Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# #015Downloading (…)rocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]#033[A#015Downloading (…)rocessor_config.json: 100%|██████████| 342/342 [00:00<00:00, 39.4kB/s]
# #015Downloading (…)"model.safetensors";:   0%|          | 0.00/492M [00:00<?, ?B/s]#033[A
# #015Downloading (…)"model.safetensors";:   0%|          | 0.00/1.22G [00:00<?, ?B/s]#033[A#033[A
# #015Downloading (…)_encoder/config.json:   0%|          | 0.00/617 [00:00<?, ?B/s]#033[A#033[A#033[A#015Downloading (…)_encoder/config.json: 100%|██████████| 617/617 [00:00<00:00, 80.1kB/s]
# #015Downloading (…)cheduler_config.json:   0%|          | 0.00/308 [00:00<?, ?B/s]#033[A#033[A#033[A#015Downloading (…)cheduler_config.json: 100%|██████████| 308/308 [00:00<00:00, 40.9kB/s]
# #015Downloading (…)_checker/config.json:   0%|          | 0.00/4.72k [00:00<?, ?B/s]#033[A#033[A#033[A
# #015Downloading (…)cial_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]#033[A#033[A#033[A#033[A#015Downloading (…)_checker/config.json: 100%|██████████| 4.72k/4.72k [00:00<00:00, 269kB/s]
# #015Downloading (…)tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]#033[A#033[A#033[A#015Downloading (…)cial_tokens_map.json: 100%|██████████| 472/472 [00:00<00:00, 26.9kB/s]
# #015Fetching 15 files:  20%|██        | 3/15 [00:00<00:00, 21.80it/s]#015Downloading (…)tokenizer/merges.txt: 100%|██████████| 525k/525k [00:00<00:00, 32.1MB/s]
# #015Downloading (…)okenizer_config.json:   0%|          | 0.00/806 [00:00<?, ?B/s]#033[A#033[A#033[A#015Downloading (…)okenizer_config.json: 100%|██████████| 806/806 [00:00<00:00, 304kB/s]
# #015Downloading (…)"model.safetensors";:   2%|▏         | 10.5M/492M [00:00<00:05, 86.7MB/s]#033[A
# #015Downloading (…)_model.safetensors";:   0%|          | 0.00/3.44G [00:00<?, ?B/s]#033[A#033[A#033[A
# #015Downloading (…)819/unet/config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]#033[A#033[A#033[A#033[A#015Downloading (…)819/unet/config.json: 100%|██████████| 743/743 [00:00<00:00, 297kB/s]
# #015Downloading (…)tokenizer/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]#033[A#033[A#033[A#033[A
# #015Downloading (…)"model.safetensors";:   1%|          | 10.5M/1.22G [00:00<00:19, 62.6MB/s]#033[A#033[A#015Downloading (…)tokenizer/vocab.json: 100%|██████████| 1.06M/1.06M [00:00<00:00, 40.3MB/s]
# #015Downloading (…)_model.safetensors";:   1%|          | 31.5M/3.44G [00:00<00:12, 281MB/s]#033[A#033[A#033[A
# #015Downloading (…)"model.safetensors";:   3%|▎         | 31.5M/1.22G [00:00<00:09, 128MB/s] #033[A#033[A
# #015Downloading (…)"model.safetensors";:   6%|▋         | 31.5M/492M [00:00<00:04, 114MB/s] #033[A
# #015Downloading (…)_model.safetensors";:   2%|▏         | 73.4M/3.44G [00:00<00:10, 315MB/s]#033[A#033[A#033[A
# #015Downloading (…)"model.safetensors";:   5%|▌         | 62.9M/1.22G [00:00<00:05, 197MB/s]#033[A#033[A
# #015Downloading (…)"model.safetensors";:  13%|█▎        | 62.9M/492M [00:00<00:02, 174MB/s]#033[A
# #015Downloading (…)_model.safetensors";:   3%|▎         | 105M/3.44G [00:00<00:10, 306MB/s] #033[A#033[A#033[A
# #015Downloading (…)"model.safetensors";:   8%|▊         | 94.4M/1.22G [00:00<00:04, 235MB/s]#033[A#033[A
# #015Downloading (…)"model.safetensors";:  19%|█▉        | 94.4M/492M [00:00<00:02, 194MB/s]#033[A
# #015Downloading (…)_model.safetensors";:   4%|▍         | 136M/3.44G [00:00<00:10, 301MB/s]#033[A#033[A#033[A
# #015Downloading (…)"model.safetensors";:  10%|█         | 126M/1.22G [00:00<00:04, 255MB/s] #033[A#033[A
# #015Downloading (…)"model.safetensors";:  26%|██▌       | 126M/492M [00:00<00:01, 225MB/s] #033[A
# #015Downloading (…)_model.safetensors";:   5%|▍         | 168M/3.44G [00:00<00:11, 291MB/s]#033[A#033[A#033[A
# #015Downloading (…)"model.safetensors";:  13%|█▎        | 157M/1.22G [00:00<00:03, 270MB/s]#033[A#033[A
# #015Downloading (…)"model.safetensors";:  32%|███▏      | 157M/492M [00:00<00:01, 243MB/s]#033[A
# #015Downloading (…)_model.safetensors";:   6%|▌         | 210M/3.44G [00:00<00:10, 306MB/s]#033[A#033[A#033[A
# #015Downloading (…)"model.safetensors";:  16%|█▌        | 189M/1.22G [00:00<00:04, 253MB/s]#033[A#033[A
# #015Downloading (…)"model.safetensors";:  38%|███▊      | 189M/492M [00:00<00:01, 254MB/s]#033[A
# #015Downloading (…)_model.safetensors";:   7%|▋         | 241M/3.44G [00:00<00:10, 306MB/s]#033[A#033[A#033[A
# #015Downloading (…)"model.safetensors";:  18%|█▊        | 220M/1.22G [00:00<00:03, 263MB/s]#033[A#033[A
# #015Downloading (…)"model.safetensors";:  45%|████▍     | 220M/492M [00:00<00:01, 271MB/s]#033[A
# #015Downloading (…)_model.safetensors";:   8%|▊         | 273M/3.44G [00:00<00:10, 300MB/s]#033[A#033[A#033[A
# #015Downloading (…)"model.safetensors";:  21%|██        | 252M/1.22G [00:01<00:03, 271MB/s]#033[A#033[A
# #015Downloading (…)"model.safetensors";:  51%|█████     | 252M/492M [00:01<00:00, 273MB/s]#033[A
# #015Downloading (…)_model.safetensors";:   9%|▉         | 315M/3.44G [00:01<00:09, 321MB/s]#033[A#033[A#033[A
# #015Downloading (…)"model.safetensors";:  23%|██▎       | 283M/1.22G [00:01<00:03, 261MB/s]#033[A#033[A
# #015Downloading (…)"model.safetensors";:  58%|█████▊    | 283M/492M [00:01<00:00, 282MB/s]#033[A
# #015Downloading (…)_model.safetensors";:  10%|█         | 357M/3.44G [00:01<00:09, 319MB/s]#033[A#033[A#033[A
# #015Downloading (…)"model.safetensors";:  64%|██████▍   | 315M/492M [00:01<00:00, 286MB/s]#033[A
# #015Downloading (…)"model.safetensors";:  27%|██▋       | 325M/1.22G [00:01<00:03, 277MB/s]#033[A#033[A
# #015Downloading (…)"model.safetensors";:  70%|███████   | 346M/492M [00:01<00:00, 289MB/s]#033[A
# #015Downloading (…)"model.safetensors";:  29%|██▉       | 357M/1.22G [00:01<00:03, 279MB/s]#033[A#033[A
# #015Downloading (…)_model.safetensors";:  12%|█▏        | 398M/3.44G [00:01<00:11, 272MB/s]#033[A#033[A#033[A
# #015Downloading (…)"model.safetensors";:  77%|███████▋  | 377M/492M [00:01<00:00, 289MB/s]#033[A
# #015Downloading (…)"model.safetensors";:  32%|███▏      | 388M/1.22G [00:01<00:03, 274MB/s]#033[A#033[A
# #015Downloading (…)_model.safetensors";:  13%|█▎        | 430M/3.44G [00:01<00:11, 263MB/s]#033[A#033[A#033[A
# #015Downloading (…)"model.safetensors";:  83%|████████▎ | 409M/492M [00:01<00:00, 281MB/s]#033[A
# #015Downloading (…)"model.safetensors";:  34%|███▍      | 419M/1.22G [00:01<00:03, 265MB/s]#033[A#033[A
# #015Downloading (…)_model.safetensors";:  13%|█▎        | 461M/3.44G [00:01<00:10, 272MB/s]#033[A#033[A#033[A
# #015Downloading (…)"model.safetensors";:  89%|████████▉ | 440M/492M [00:01<00:00, 286MB/s]#033[A
# #015Downloading (…)"model.safetensors";:  37%|███▋      | 451M/1.22G [00:01<00:03, 252MB/s]#033[A#033[A
# #015Downloading (…)_model.safetensors";:  15%|█▍        | 503M/3.44G [00:01<00:10, 286MB/s]#033[A#033[A#033[A
# #015Downloading (…)"model.safetensors";:  98%|█████████▊| 482M/492M [00:01<00:00, 299MB/s]#033[A#015Downloading (…)"model.safetensors";: 100%|██████████| 492M/492M [00:01<00:00, 257MB/s]
# #015Downloading (…)"model.safetensors";:  40%|███▉      | 482M/1.22G [00:01<00:02, 252MB/s]#033[A#033[A
# #015Downloading (…)_model.safetensors";:  16%|█▌        | 545M/3.44G [00:01<00:09, 305MB/s]#033[A#033[A#033[A
# #015Downloading (…)"model.safetensors";:  42%|████▏     | 514M/1.22G [00:02<00:02, 265MB/s]#033[A#033[A
# #015Downloading (…)_model.safetensors";:  17%|█▋        | 577M/3.44G [00:01<00:09, 301MB/s]#033[A#033[A#033[A
# #015Downloading (…)"model.safetensors";:  45%|████▍     | 545M/1.22G [00:02<00:02, 278MB/s]#033[A#033[A
# #015Downloading (…)_model.safetensors";:  18%|█▊        | 619M/3.44G [00:02<00:08, 322MB/s]#033[A#033[A#033[A
# #015Downloading (…)"model.safetensors";:  47%|████▋     | 577M/1.22G [00:02<00:02, 281MB/s]#033[A#033[A
# #015Downloading (…)_model.safetensors";:  19%|█▉        | 661M/3.44G [00:02<00:08, 343MB/s]#033[A#033[A#033[A
# #015Downloading (…)"model.safetensors";:  50%|█████     | 608M/1.22G [00:02<00:02, 289MB/s]#033[A#033[A
# #015Downloading (…)_model.safetensors";:  20%|██        | 703M/3.44G [00:02<00:08, 334MB/s]#033[A#033[A#033[A
# #015Downloading (…)"model.safetensors";:  53%|█████▎    | 640M/1.22G [00:02<00:01, 296MB/s]#033[A#033[A
# #015Downloading (…)_model.safetensors";:  22%|██▏       | 744M/3.44G [00:02<00:07, 340MB/s]#033[A#033[A#033[A
# #015Downloading (…)"model.safetensors";:  56%|█████▌    | 682M/1.22G [00:02<00:01, 300MB/s]#033[A#033[A
# #015Downloading (…)_model.safetensors";:  23%|██▎       | 786M/3.44G [00:02<00:08, 331MB/s]#033[A#033[A#033[A
# #015Downloading (…)"model.safetensors";:  59%|█████▊    | 713M/1.22G [00:02<00:01, 293MB/s]#033[A#033[A
# #015Downloading (…)_model.safetensors";:  24%|██▍       | 828M/3.44G [00:02<00:07, 341MB/s]#033[A#033[A#033[A
# #015Downloading (…)"model.safetensors";:  61%|██████    | 744M/1.22G [00:02<00:01, 295MB/s]#033[A#033[A
# #015Downloading (…)_model.safetensors";:
encoder/config.json:   0%|          | 0.00/617 [00:00<?, ?B/s]#015Downloading (…)_encoder/config.json: 100%|██████████| 617/617 [00:00<00:00, 300kB/s]
# You are using a model of type clip_text_model to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# #015Downloading (…)"model.safetensors";:   0%|          | 0.00/492M [00:00<?, ?B/s]#015Downloading (…)"model.safetensors";:   2%|▏         | 10.5M/492M [00:00<00:05, 83.3MB/s]#015Downloading (…)"model.safetensors";:   4%|▍         | 21.0M/492M [00:00<00:05, 89.8MB/s]#015Downloading (…)"model.safetensors";:  11%|█         | 52.4M/492M [00:00<00:02, 181MB/s] #015Downloading (…)"model.safetensors";:  19%|█▉        | 94.4M/492M [00:00<00:01, 250MB/s]#015Downloading (…)"model.safetensors";:  26%|██▌       | 126M/492M [00:00<00:01, 267MB/s] #015Downloading (…)"model.safetensors";:  32%|███▏      | 157M/492M [00:00<00:01, 269MB/s]#015Downloading (…)"model.safetensors";:  40%|████      | 199M/492M [00:00<00:01, 273MB/s]#015Downloading (…)"model.safetensors";:  49%|████▉     | 241M/492M [00:00<00:00, 290MB/s]#015Downloading (…)"model.safetensors";:  58%|█████▊    | 283M/492M [00:01<00:00, 314MB/s]#015Downloading (…)"model.safetensors";:  66%|██████▌   | 325M/492M [00:01<00:00, 332MB/s]#015Downloading (…)"model.safetensors";:  75%|███████▍  | 367M/492M [00:01<00:00, 313MB/s]#015Downloading (…)"model.safetensors";:  83%|████████▎ | 409M/492M [00:01<00:00, 319MB/s]#015Downloading (…)"model.safetensors";:  92%|█████████▏| 451M/492M [00:01<00:00, 329MB/s]#015Downloading (…)"model.safetensors";: 100%|██████████| 492M/492M [00:01<00:00, 336MB/s]#015Downloading (…)"model.safetensors";: 100%|██████████| 492M/492M [00:01<00:00, 289MB/s]
# /opt/conda/lib/python3.9/site-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('${LD_LIBRARY_PATH}')}
#   warn(
#  Loaded model.
#  Allocated: 0.0GB
#  Reserved: 0.0GB
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please submit your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# For effortless bug reporting copy-paste your error into this form: https://docs.google.com/forms/d/e/1FAIpQLScPB8emS3Thkp66nvqwmjTEgxp8Y9ufuWTzFyr9kJ5AoI47dQ/viewform?usp=sf_link
# ================================================================================
# CUDA SETUP: CUDA runtime path found: /opt/conda/lib/libcudart.so
# CUDA SETUP: Highest compute capability among GPUs detected: 7.5
# CUDA SETUP: Detected CUDA version 113
# CUDA SETUP: Loading binary /opt/conda/lib/python3.9/site-packages/bitsandbytes/libbitsandbytes_cuda113.so...
#  Scheduler, EMA Loaded.
#  Allocated: 5.5GB
#  Reserved: 5.6GB
# ***** Running training *****
#   Num examples = 6
#   Num batches each epoch = 6
#   Num Epochs = 50
#   Instantaneous batch size per device = 1
#   Total train batch size (w. parallel, distributed & accumulation) = 1
#   Gradient Accumulation steps = 1
#   Total optimization steps = 300
#   Actual steps: 300
#    Training settings: CPU: False Adam: True, Prec: fp16, Grad: True, TextTr: False EM: True, LR: 2e-06 LORA:False
#  Allocated: 5.5GB
#  Reserved: 5.6GB
# #015  0%|          | 0/300 [00:00<?, ?it/s]#015Steps:   0%|          | 0/300 [00:00<?, ?it/s]You're using a CLIPTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#  Step 0 completed.
#  Allocated: 7.4GB
#  Reserved: 7.7GB
#  Step 5 completed.
#  Allocated: 7.4GB
#  Reserved: 7.7GB
# #015Steps:   0%|          | 0/300 [00:01<?, ?it/s, loss=0.573, lr=2e-6, vram=7.4/7.7GB]#015Steps:   0%|          | 1/300 [00:01<06:33,  1.32s/it, loss=0.573, lr=2e-6, vram=7.4/7.7GB]#015Steps:   1%|          | 2/300 [00:02<06:17,  1.27s/it, loss=0.573, lr=2e-6, vram=7.4/7.7GB]#015Steps:   1%|          | 2/300 [00:03<06:17,  1.27s/it, loss=0.0756, lr=2e-6, vram=7.4
lr=2e-6, vram=7.4/7.7GB]
# #015Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]#033[A#015Fetching 15 files: 100%|██████████| 15/15 [00:00<00:00, 117597.31it/s]
# #015Steps:  98%|█████████▊| 294/300 [16:26<00:11,  1.96s/it, loss=0.111, lr=2e-6, vram=7.4/7.7GB]#015Steps:  98%|█████████▊| 295/300 [16:26<00:27,  5.52s/it, loss=0.111, lr=2e-6, vram=7.4/7.7GB]#015Steps:  99%|█████████▊| 296/300 [16:28<00:16,  4.23s/it, loss=0.111, lr=2e-6, vram=7.4/7.7GB]#015Steps:  99%|█████████▊| 296/300 [16:29<00:16,  4.23s/it, loss=0.356, lr=2e-6, vram=7.4/7.7GB]#015Steps:  99%|█████████▉| 297/300 [16:29<00:09,  3.33s/it, loss=0.356, lr=2e-6, vram=7.4/7.7GB]#015Steps:  99%|█████████▉| 298/300 [16:30<00:05,  2.70s/it, loss=0.356, lr=2e-6, vram=7.4/7.7GB]#015Steps:  99%|█████████▉| 298/300 [16:31<00:05,  2.70s/it, loss=0.222, lr=2e-6, vram=7.4/7.7GB]#015Steps: 100%|█████████▉| 299/300 [16:31<00:02,  2.25s/it, loss=0.222, lr=2e-6, vram=7.4/7.7GB]#015Steps: 100%|██████████| 300/300 [16:32<00:00,  1.94s/it, loss=0.222, lr=2e-6, vram=7.4/7.7GB]
# #015Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]#033[A#015Fetching 15 files: 100%|██████████| 15/15 [00:00<00:00, 149796.57it/s]
# #015Steps: 100%|██████████| 300/300 [16:46<00:00,  3.35s/it, loss=0.222, lr=2e-6, vram=7.4/7.7GB]
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# #011- Avoid using `tokenizers` before the fork if possible
# #011- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# cp /opt/ml/model/model_index.json s3://sagemaker-us-east-1-596030579944/dreambooth/model/sd-dreambooth-finetuning-quickupload-2023-02-21-03-04-13-395/model_index.json
# cp /opt/ml/model/logging/dreambooth/events.out.tfevents.1676949637.ip-10-0-156-201.ec2.internal.20.0 s3://sagemaker-us-east-1-596030579944/dreambooth/model/sd-dreambooth-finetuning-quickupload-2023-02-21-03-04-13-395/logging/dreambooth/events.out.tfevents.1676949637.ip-10-0-156-201.ec2.internal.20.0
# cp /opt/ml/model/unet/config.json s3://sagemaker-us-east-1-596030579944/dreambooth/model/sd-dreambooth-finetuning-quickupload-2023-02-21-03-04-13-395/unet/config.json
# cp /opt/ml/model/scheduler/scheduler_config.json s3://sagemaker-us-east-1-596030579944/dreambooth/model/sd-dreambooth-finetuning-quickupload-2023-02-21-03-04-13-395/scheduler/scheduler_config.json
# cp /opt/ml/model/text_encoder/config.json s3://sagemaker-us-east-1-596030579944/dreambooth/model/sd-dreambooth-finetuning-quickupload-2023-02-21-03-04-13-395/text_encoder/config.json
# cp /opt/ml/model/feature_extractor/preprocessor_config.json s3://sagemaker-us-east-1-596030579944/dreambooth/model/sd-dreambooth-finetuning-quickupload-2023-02-21-03-04-13-395/feature_extractor/preprocessor_config.json
# cp /opt/ml/model/tokenizer/tokenizer_config.json s3://sagemaker-us-east-1-596030579944/dreambooth/model/sd-dreambooth-finetuning-quickupload-2023-02-21-03-04-13-395/tokenizer/tokenizer_config.json
# cp /opt/ml/model/vae/config.json s3://sagemaker-us-east-1-596030579944/dreambooth/model/sd-dreambooth-finetuning-quickupload-2023-02-21-03-04-13-395/vae/config.json
# cp /opt/ml/model/tokenizer/special_tokens_map.json s3://sagemaker-us-east-1-596030579944/dreambooth/model/sd-dreambooth-finetuning-quickupload-2023-02-21-03-04-13-395/tokenizer/special_tokens_map.json
# cp /opt/ml/model/tokenizer/vocab.json s3://sagemaker-us-east-1-596030579944/dreambooth/model/sd-dreambooth-finetuning-quickupload-2023-02-21-03-04-13-395/tokenizer/vocab.json
# cp /opt/ml/model/tokenizer/merges.txt s3://sagemaker-us-east-1-596030579944/dreambooth/model/sd-dreambooth-finetuning-quickupload-2023-02-21-03-04-13-395/tokenizer/merges.txt
# cp /opt/ml/model/vae/diffusion_pytorch_model.bin s3://sagemaker-us-east-1-596030579944/dreambooth/model/sd-dreambooth-finetuning-quickupload-2023-02-21-03-04-13-395/vae/diffusion_pytorch_model.bin
# cp /opt/ml/model/text_encoder/pytorch_model.bin s3://sagemaker-us-east-1-596030579944/dreambooth/model/sd-dreambooth-finetuning-quickupload-2023-02-21-03-04-13-395/text_encoder/pytorch_model.bin
# cp /opt/ml/model/unet/diffusion_pytorch_model.bin s3://sagemaker-us-east-1-596030579944/dreambooth/model/sd-dreambooth-finetuning-quickupload-2023-02-21-03-04-13-395/unet/diffusion_pytorch_model.bin
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# #011- Avoid using `tokenizers` before the fork if possible
# #011- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#  CLEANUP:
#  Allocated: 7.4GB
#  Reserved: 10.8GB
#  Cleanup completed.
#  Allocated: 7.4GB
#  Reserved: 7.7GB
#  Cleanup Complete.
#  Allocated: 7.4GB
#  Reserved: 7.7GB
#  Training completed, total steps: 300
#  Allocated: 7.4GB
#  Reserved: 7.7GB
# begin quick upload s3 , skip tgz
# clear /opt/ml/model
# 2023-02-21 03:37:39,805 sagemaker-training-toolkit INFO     Reporting training SUCCESS
#
# 2023-02-21 03:37:57 Uploading - Uploading generated training model
# 2023-02-21 03:37:57 Completed - Training job completed
# Training seconds: 1951
# Billable seconds: 1951

# %%
dreambooth_model_data = estimator.model_data
print("Model artifact saved at:\n", dreambooth_model_data)

# %% [markdown]
# #### 4. Testing
#   you can use inference notebook load your new model
